# %%
import networkx as nx
import pandas as pd
import numpy as np

# %%
G = nx.Graph([(0,1), (1,2)])
q = set()
q.update(G.adj[1])
# Out:
# {0, 2}

# %%
df = pd.DataFrame({"color": [0,1,0,1]})
arr = np.array([5,6])
c = np.array(df["color"])
print(arr[c])
# Out:
# [5 6 5 6]

# %%
import numpy as np
a = np.array([1,2,0,3])
b = (a > 1).nonzero()
sum(a[b])
# Out:
# np.int64(5)
